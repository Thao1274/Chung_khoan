# %%
import requests
import json

# headers không thay đổi nó đại diện cho trang web mà bạn đang truy cập
headers = {
  'sec-ch-ua-platform': '"Windows"',
  'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....W15vfJ19kJSj9-nKjan1fRrHGXWSoJLou2zhMSRtoLCMqxdccOyRfzKB4GWb9Tn8iGlxcKSQR_KZBIuE67nV-Ulyl0acC4VHOPUZ7Yxke8yPeNbiffpHGKWVYXHPqSStqwZ6Gu0G1dG5vm9rI0g6JPI9ggGXJIMjz5j3KHaNtxvM2cU1kfpBshKoIsDETH6GqFbodYHXYGdk6hVjextlMoPst-eAa7ysnrHUTeDwBZ1peMKDDii0XCWoci17TS5z1c3ZGOIzNaBTvTQ1II6jaK0Oibia-Xw3vMXpfXWmFdUFCef87CUC7wLz_c66070NHqH9ht4Nwiu8F3BsNPqc_g',
  'Referer': 'https://tcinvest.tcbs.com.vn/',
  'Accept-language': 'vi',
  'sec-ch-ua': '"Not)A;Brand";v="8", "Chromium";v="138", "Google Chrome";v="138"',
  'sec-ch-ua-mobile': '?0',
  'traceparent': '00-99826bce96c4bd81c43b1dbbf0ab420e-d58cfd58094b5d46-01',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36',
  'Accept': 'application/json',
  'Content-Type': 'application/json',
  'tracestate': 'es=s:1'
}

def crawl(symbol, headers, start,end, countback, interval, asset_type):
    url = f"https://apiextaws.tcbs.com.vn/stock-insight/v2/stock/bars-long-term?ticker={symbol}&type={asset_type}&resolution={interval}&to={end}&countBack={countback}"
    payload = {}
    response = requests.request("GET", url, headers=headers, data=payload)

    data = response.json()
    import pandas as pd
    df = pd.DataFrame(data['data']) 
    return df
crawl('VNM', headers,'','1715472000','100', 'W','stock')
# Out:
#        open     high      low    close    volume               tradingDate
# 0   57037.0  57204.0  53785.0  55619.0  11171800  2022-06-13T00:00:00.000Z
# 1   55369.0  61540.0  55369.0  59622.0  12429000  2022-06-20T00:00:00.000Z
# 2   59872.0  62374.0  58454.0  61456.0  13224100  2022-06-27T00:00:00.000Z
# 3   61706.0  63241.0  59963.0  62982.0  12844000  2022-07-04T00:00:00.000Z
# 4   62292.0  64449.0  61775.0  61775.0   7413800  2022-07-11T00:00:00.000Z
# ..      ...      ...      ...      ...       ...                       ...
# 95  62973.0  62973.0  61584.0  61769.0  14419780  2024-04-08T00:00:00.000Z
# 96  61769.0  61769.0  58342.0  59454.0  22019193  2024-04-15T00:00:00.000Z
# 97  59917.0  60935.0  58528.0  60194.0  11325396  2024-04-22T00:00:00.000Z
# 98  60565.0  61121.0  60102.0  60750.0   4535266  2024-05-02T00:00:00.000Z
# 99  60935.0  63436.0  60658.0  61584.0  19146272  2024-05-06T00:00:00.000Z
#
# [100 rows x 6 columns]

# %%
import requests

url = "https://apiextaws.tcbs.com.vn/stock-insight/v2/stock/bars-long-term?ticker=VNM&type=stock&resolution=D&to=1715472000&countBack=70"

response = requests.get(url, headers=headers)
print("Status Code:", response.status_code)
print("Response JSON:", response.text)
# Out:
# Status Code: 200
# ...

# %%
# Out:
#        open     high      low    close   volume               tradingDate
# 0   62973.0  62973.0  62510.0  62695.0  2639932  2024-03-27T00:00:00.000Z
# 1   62695.0  63343.0  62602.0  62695.0  4474441  2024-03-28T00:00:00.000Z
# 2   63343.0  63343.0  62510.0  62602.0  3487674  2024-03-29T00:00:00.000Z
# 3   62602.0  62695.0  62047.0  62047.0  4996398  2024-04-01T00:00:00.000Z
# 4   62047.0  62417.0  61769.0  62324.0  4325527  2024-04-02T00:00:00.000Z
# 5   62324.0  62324.0  61769.0  61769.0  5054063  2024-04-03T00:00:00.000Z
# 6   61769.0  63343.0  61769.0  63158.0  7477825  2024-04-04T00:00:00.000Z
# 7   63158.0  63158.0  62695.0  62880.0  4237214  2024-04-05T00:00:00.000Z
# 8   62973.0  62973.0  61954.0  62047.0  3671802  2024-04-08T00:00:00.000Z
# 9   62139.0  62324.0  61861.0  62047.0  2518780  2024-04-09T00:00:00.000Z
# 10  62139.0  62324.0  61861.0  61861.0  2767420  2024-04-10T00:00:00.000Z
# 11  61769.0  61954.0  61584.0  61676.0  2950689  2024-04-11T00:00:00.000Z
# ...
